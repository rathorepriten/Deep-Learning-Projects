jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://collectionapi.metmuseum.org/api/collection/v1/iiif/1679/preview
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://get.pxhere.com/photo/wood-chair-stool-furniture-chairs-art-exhibition-man-made-object-545829.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 30 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 30 Images on Page 3.
#
# ===============================================
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 30 Images on Page 4.
#
# ===============================================
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 30 Images on Page 5.
#
# ===============================================
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 30 Images on Page 6.
#
# ===============================================
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 30 Images on Page 7.
#
# ===============================================
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 30 Images on Page 8.
#
# ===============================================
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 30 Images on Page 9.
#
# ===============================================
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 30 Images on Page 10.
#
# ===============================================
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 30 Images on Page 11.
#
# ===============================================
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 30 Images on Page 12.
#
# ===============================================
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 30 Images on Page 13.
#
# ===============================================
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 30 Images on Page 14.
#
# ===============================================
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 30 Images on Page 15.
#
# ===============================================
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 30 Images on Page 16.
#
# ===============================================
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 30 Images on Page 17.
#
# ===============================================
#
#
#
# [!!]Indexing page: 18
#
# [%] Indexed 30 Images on Page 18.
#
# ===============================================
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 30 Images on Page 19.
#
# ===============================================
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 30 Images on Page 20.
#
# ===============================================
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 30 Images on Page 21.
#
# ===============================================
#
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 30 Images on Page 22.
#
# ===============================================
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 30 Images on Page 23.
#
# ===============================================
#
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 30 Images on Page 24.
#
# ===============================================
#
#
#
# [!!]Indexing page: 25
#
# [%] Indexed 30 Images on Page 25.
#
# ===============================================
#
#
#
# [!!]Indexing page: 26
#
# [%] Indexed 30 Images on Page 26.
#
# ===============================================
#
#
#
# [!!]Indexing page: 27
#
# [%] Indexed 30 Images on Page 27.
#
# ===============================================
#
#
#
# [!!]Indexing page: 28
#
# [%] Indexed 30 Images on Page 28.
#
# ===============================================
#
#
#
# [!!]Indexing page: 29
#
# [%] Indexed 30 Images on Page 29.
#
# ===============================================
#
#
#
# [!!]Indexing page: 30
#
# [%] Indexed 30 Images on Page 30.
#
# ===============================================
#
#
#
# [!!]Indexing page: 31
#
# [%] Indexed 30 Images on Page 31.
#
# ===============================================
#
#
#
# [!!]Indexing page: 32
#
# [%] Indexed 30 Images on Page 32.
#
# ===============================================
#
#
#
# [!!]Indexing page: 33
#
# [%] Indexed 30 Images on Page 33.
#
# ===============================================
#
#
#
# [!!]Indexing page: 34
#
# [%] Indexed 30 Images on Page 34.
#
# ===============================================
#
#
#
# [!!]Indexing page: 35
#
# [%] Indexed 30 Images on Page 35.
#
# ===============================================
#
#
#
# [!!]Indexing page: 36
#
# [%] Indexed 30 Images on Page 36.
#
# ===============================================
#
#
#
# [!!]Indexing page: 37
#
# [%] Indexed 30 Images on Page 37.
#
# ===============================================
#
#
#
# [!!]Indexing page: 38
#
# [%] Indexed 30 Images on Page 38.
#
# ===============================================
#
#
#
# [!!]Indexing page: 39
#
# [%] Indexed 30 Images on Page 39.
#
# ===============================================
#
#
#
# [!!]Indexing page: 40
#
# [%] Indexed 30 Images on Page 40.
#
# ===============================================
#
#
#
# [!!]Indexing page: 41
#
# [%] Indexed 30 Images on Page 41.
#
# ===============================================
#
#
#
# [!!]Indexing page: 42
#
# [%] Indexed 30 Images on Page 42.
#
# ===============================================
#
#
#
# [!!]Indexing page: 43
#
# [%] Indexed 30 Images on Page 43.
#
# ===============================================
#
# [%] Downloading Image #26 from https://images.bhaskarassets.com/thumb/730x0/web2images/960/2023/01/29/9_1675003253.jpg
# [Error]Invalid image, not saving https://images.bhaskarassets.com/thumb/730x0/web2images/960/2023/01/29/9_1675003253.jpg
#
# [!] Issue getting: https://images.bhaskarassets.com/thumb/730x0/web2images/960/2023/01/29/9_1675003253.jpg
# [!] Error:: Invalid image, not saving https://images.bhaskarassets.com/thumb/730x0/web2images/960/2023/01/29/9_1675003253.jpg
#
# [%] Downloading Image #26 from https://www.greensoul.online/cdn/shop/files/jupiter_superb_hb_black_lifestyle_4_97001b0b-cd8d-403d-8f57-d69ce82dc969_720x.jpg?v=1742942052
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://www
.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from http://images2.fanpop.com/images/photos/8400000/Movie-Posters-movies-8405245-1224-1773.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://images.pexels.com/photos/3052727/pexels-photo-3052727.jpeg?auto=compress&amp;cs=tinysrgb&amp;dpr=1&amp;w=500
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://mir-s3-cdn-cf.behance.net/project_modules/1400_opt_1/c15b54150830909.630129cb0cfa0.png
# [%] File Downloaded !
#
# [%] Downloading Image #18 from http://flashbak.com/wp-content/uploads/2016/10/1962-this-classic-travel-poster-promotes-transport-to-Chicago-IL-via-Braniff-International-Airways.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://cdn.mos.cms.futurecdn.net/V2WAzuk3JAcTN4CobbeMkU.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://i5.walmartimages.com/asr/6414a875-ef08-4259-90b6-b990a83b3351_1.1f4e6e3ad5236470d57594c87b51e6d0.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://www.noupe.com/wp-content/uploads/2022/08/image-23-670x1024.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://cached.imagescaler.hbpl.co.uk/resize/scaleWidth/952/cached.offlinehbpl.hbpl.co.uk/news/OMC/Posters.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://i.etsystatic.com/18867086/r/il/795495/4440624655/il_fullxfull.4440624655_pnbo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://i.pinimg.com/originals/75/87/53/758753e42ae01926a714a49e0927133c.png
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://geekszine.com/wp-content/uploads/2012/02/14.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://images-cdn.ubuy.co.in/63747f7b260c4c69765f1ab3-woonkit-vintage-rock-band-posters-for.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://marketplace.canva.com/EAFBbU9WSF8/1/0/1131w/canva-blue-green-simple-drama-romance-movie-promotion-poster-T7_ewUsS_28.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://mlpnk72yciwc.i.optimole.com/cqhiHLc.IIZS~2ef73/w:auto/h:auto/q:75/https://bleedingcool.com/wp-content/uploads/2023/05/flash_ver10_xlg.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://cdn.mos.cms.futurecdn.net/5mV4nZwDJmYC4GPLzdcLsC-1200-80.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from http://www.slashfilm.com/wp/wp-content/images/2017-bestposter-thorragnarok.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 30 images.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
import numpy as np
import os
import cv2

# %%
datadir= "/Users/rathorepriten/Desktop/DL_projs/image"
categories = ['Chair','Posters']
target=[]
flat_data=[]
for i in categories:
  path = os.path.join(datadir,i)
  print(path)
  for img in os.listdir(path):
    img_arr = imread(os.path.join(path,img))
    gray_img = cv2.cvtColor(img_arr, cv2.COLOR_BGR2GRAY)
    img_resize = resize(gray_img,(150,150,1)) 
    flat_data.append(np.ndarray.flatten(img_resize))
    target.append(i)

x = np.array(flat_data)
y = np.array(target)
# Out:
# /Users/rathorepriten/Desktop/DL_projs/image/Chair
# /Users/rathorepriten/Desktop/DL_projs/image/Posters

# %%
df = pd.DataFrame(flat_data)
df['Target']=target

# %%
df['Target'].value_counts()
# Out:
# Target
# Chair      30
# Posters    30
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0,stratify=y)
from sklearn.svm import SVC
model = SVC()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_pred,y_test)
# Out:
# 0.8666666666666667

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_pred,y_test)
# Out:
# 0.8666666666666667

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[7, 1],
#        [1, 6]])

# %%
from sklearn.model_selection import GridSearchCV
model = SVC()
param = {
    'kernel':['linear','rbf','poly'],
    'C':[0.1,1,10,100]
}
grid = GridSearchCV(model,param,cv=5)
grid.fit(x_train,y_train)
grid.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
model = SVC(C=0.1,kernel= 'linear')

# %%
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_pred,y_test)
# Out:
# 0.6666666666666666

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[7, 4],
#        [1, 3]])
